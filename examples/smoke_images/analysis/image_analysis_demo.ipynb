# %% [markdown]
# # Native image smoke analysis
# Run after a successful three-image MouseGaze session.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'examples/smoke_images/analysis/analyze_output.py', '--output-root', 'output'], check=True)

# %% [markdown]
# Outputs are written under the newest `output/<session>/analysis_image_demo/` directory.
